# %%
car_ages = [0, 9, 4, 8, 7, 20, 19, 1, 6, 15]
car_ages_descending = sorted(car_ages, reverse=True)

# %%
oldest, second_oldest, *others = car_ages_descending
print(oldest, second_oldest, others)
# Out:
# 20 19 [15, 9, 8, 7, 6, 4, 1, 0]

# %%
oldest, *others, youngest = car_ages_descending
print(oldest, others, youngest)
# Out:
# 20 [19, 15, 9, 8, 7, 6, 4, 1] 0

# %%
*others, second_youngest, youngest = car_ages_descending
print(others, second_youngest, youngest)
# Out:
# [20, 19, 15, 9, 8, 7, 6, 4] 1 0

# %%
*others = car_ages_descending
# Out:
#   File "<ipython-input-15-77c6f344fe32>", line 1
#     *others = car_ages_descending
#                                  ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
car_inventory = {'시내': ('그랜저', '아반떼', '타코'),
                 '공항': ('제네시스 쿠페', '소나타', 'K5', '엑센트')}

# %%
car_inventory.items()
# Out:
# dict_items([('시내', ('그랜저', '아반떼', '타코')), ('공항', ('제네시스 쿠페', '소나타', 'K5', '엑센트'))])

# %%
car_inventory
# Out:
# {'공항': ('제네시스 쿠페', '소나타', 'K5', '엑센트'), '시내': ('그랜저', '아반떼', '타코')}

# %%
((loc1, (best1, *rest1)),
 (loc2, (best2, *rest2))) = car_inventory.items()
print(f'{loc1} 최고는 {best1}, 나머지는 {len(rest1)} 종')
print(f'{loc2} 최고는 {best2}, 나머지는 {len(rest2)} 종')
# Out:
# 시내 최고는 그랜저, 나머지는 2 종
# 공항 최고는 제네시스 쿠페, 나머지는 3 종

# %% [markdown]
# 빈 리스트에서는 오류가 난다.
# => 최소 N개의 요소를 가지고 있다는 것을 알고 있으면 유용하다.(최소한 빈리스트가 아닌 것은 보장해야한다.)

# %%
first, *rest = []
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3113b54c318b> in <module>()
# ----> 1 first, *rest = []
#
# ValueError: not enough values to unpack (expected at least 1, got 0)

# %%
short_list = [1, 2]
first, second, *rest = short_list
print(first, second, rest)
# Out:
# 1 2 []

# %%
def generate_csv():
	yield ('Date', 'Make' , 'Model', 'Year', 'Price')
	for i in range(100):
		yield ('2019-03-25', 'Honda', 'Fit' , '2010', '$3400')
		yield ('2019-03-26', 'Ford', 'F150' , '2008', '$2400')

# %%
a = generate_csv()

# %%
next(a)
# Out:
# ('2019-03-26', 'Ford', 'F150', '2008', '$2400')

# %%
it = generate_csv()
header, *rows = it
print(f'CSV 헤더: {header}')
print(f'행 수: {len(rows)}')
# Out:
# CSV 헤더: ('Date', 'Make', 'Model', 'Year', 'Price')
# 행 수: 200
